# %%
import pandas as pd

# %%
# !wget "https://data.lacity.org/api/views/63jg-8b9z/rows.csv?accessType=DOWNLOAD" -O "crime_2010_2019.csv"
# Out:
# --2023-03-26 21:36:17--  https://data.lacity.org/api/views/63jg-8b9z/rows.csv?accessType=DOWNLOAD
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving data.lacity.org (data.lacity.org)... 52.206.140.199, 52.206.68.26, 52.206.140.205
# Connecting to data.lacity.org (data.lacity.org)|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘crime_2010_2019.csv’
#
# crime_2010_2019.csv     [          <=>       ] 511.52M  6.62MB/s    in 89s
#
# 2023-03-26 21:37:51 (5.74 MB/s) - ‘crime_2010_2019.csv’ saved [536364291]

# %%
data = pd.read_csv("crime_2010_2019.csv")

# %%
data
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2119792  190506304  02/22/2019 12:00:00 AM  02/22/2019 12:00:00 AM       840
# 2119793  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2119794  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2119795  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2119796  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
# ...

# %%
data.loc[:,["Date Rptd", "DATE OCC"]]
# Out:
#                       Date Rptd                DATE OCC
# 0        02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM
# 1        09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM
# 2        08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM
# 3        01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM
# 4        01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM
# ...                         ...                     ...
# 2119792  02/22/2019 12:00:00 AM  02/22/2019 12:00:00 AM
# 2119793  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM
# 2119794  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM
# 2119795  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM
# 2119796  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM
#
# [2119797 rows x 2 columns]

# %%
date_of_report = data["Date Rptd"].values.tolist()
date_of_crime = data["DATE OCC"].values.tolist()

# %%
date_of_report
# Out:
# ['02/20/2010 12:00:00 AM',
#  '09/13/2010 12:00:00 AM',
#  '08/09/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/03/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/08/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/17/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/26/2010 12:00:00 AM',
#  '01/28/2010 12:00:00 AM',
#  '01/30/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/02/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/06/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/10/2010 12:00:00 AM',
# ...

# %%
date_of_crime
# Out:
# ['02/20/2010 12:00:00 AM',
#  '09/12/2010 12:00:00 AM',
#  '08/09/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/02/2010 12:00:00 AM',
#  '01/04/2010 12:00:00 AM',
#  '01/07/2010 12:00:00 AM',
#  '01/08/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/06/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/26/2010 12:00:00 AM',
#  '01/28/2010 12:00:00 AM',
#  '01/29/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '02/03/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/06/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/08/2010 12:00:00 AM',
# ...

# %%
report = []
crime = []
for i in range(len(date_of_report)):
  report.append(str(date_of_report[i]))
for i in range(len(date_of_crime)):
  crime.append(str(date_of_crime[i]))

# %%
report
# Out:
# ['02/20/2010 12:00:00 AM',
#  '09/13/2010 12:00:00 AM',
#  '08/09/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/03/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/08/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/17/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/26/2010 12:00:00 AM',
#  '01/28/2010 12:00:00 AM',
#  '01/30/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/02/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/06/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/10/2010 12:00:00 AM',
# ...

# %%
crime
# Out:
# ['02/20/2010 12:00:00 AM',
#  '09/12/2010 12:00:00 AM',
#  '08/09/2010 12:00:00 AM',
#  '01/05/2010 12:00:00 AM',
#  '01/02/2010 12:00:00 AM',
#  '01/04/2010 12:00:00 AM',
#  '01/07/2010 12:00:00 AM',
#  '01/08/2010 12:00:00 AM',
#  '01/09/2010 12:00:00 AM',
#  '01/06/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/14/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/15/2010 12:00:00 AM',
#  '01/16/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/23/2010 12:00:00 AM',
#  '01/26/2010 12:00:00 AM',
#  '01/28/2010 12:00:00 AM',
#  '01/29/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '01/31/2010 12:00:00 AM',
#  '02/03/2010 12:00:00 AM',
#  '02/01/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/06/2010 12:00:00 AM',
#  '02/05/2010 12:00:00 AM',
#  '02/08/2010 12:00:00 AM',
# ...

# %%
for i in range(len(report)):
  report[i] = report[i][-16:-12] + "-" + report[i][:2] + "-" + report[i][3:5]
report
# Out:
# ['2010-02-20',
#  '2010-09-13',
#  '2010-08-09',
#  '2010-01-05',
#  '2010-01-03',
#  '2010-01-05',
#  '2010-01-08',
#  '2010-01-09',
#  '2010-01-09',
#  '2010-01-09',
#  '2010-01-14',
#  '2010-01-15',
#  '2010-01-15',
#  '2010-01-16',
#  '2010-01-16',
#  '2010-01-17',
#  '2010-01-23',
#  '2010-01-23',
#  '2010-01-23',
#  '2010-01-26',
#  '2010-01-28',
#  '2010-01-30',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-02-01',
#  '2010-02-01',
#  '2010-02-01',
#  '2010-02-01',
#  '2010-02-05',
#  '2010-02-02',
#  '2010-02-05',
#  '2010-02-06',
#  '2010-02-05',
#  '2010-02-10',
#  '2010-02-08',
#  '2010-02-11',
#  '2010-02-11',
#  '2010-02-11',
#  '2010-02-13',
#  '2010-02-13',
#  '2010-02-15',
#  '2010-02-15',
#  '2010-02-16',
#  '2010-02-17',
#  '2010-02-20',
#  '2010-02-20',
#  '2010-02-20',
#  '2010-02-20',
#  '2010-02-21',
#  '2010-02-25',
#  '2010-02-26',
#  '2010-02-27',
#  '2010-02-28',
#  '2010-03-01',
#  '2010-03-01',
#  '2010-08-01',
#  '2010-02-28',
#  '2010-03-01',
# ...

# %%
for i in range(len(crime)):
  crime[i] = crime[i][-16:-12] + "-" + crime[i][:2] + "-" + crime[i][3:5]
crime
# Out:
# ['2010-02-20',
#  '2010-09-12',
#  '2010-08-09',
#  '2010-01-05',
#  '2010-01-02',
#  '2010-01-04',
#  '2010-01-07',
#  '2010-01-08',
#  '2010-01-09',
#  '2010-01-06',
#  '2010-01-14',
#  '2010-01-14',
#  '2010-01-15',
#  '2010-01-15',
#  '2010-01-15',
#  '2010-01-16',
#  '2010-01-23',
#  '2010-01-23',
#  '2010-01-23',
#  '2010-01-26',
#  '2010-01-28',
#  '2010-01-29',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-01-31',
#  '2010-02-03',
#  '2010-02-01',
#  '2010-02-05',
#  '2010-02-06',
#  '2010-02-05',
#  '2010-02-08',
#  '2010-02-08',
#  '2010-02-10',
#  '2010-02-10',
#  '2010-02-11',
#  '2010-02-13',
#  '2010-02-13',
#  '2010-02-14',
#  '2010-02-15',
#  '2010-02-16',
#  '2010-02-17',
#  '2010-02-19',
#  '2010-02-19',
#  '2010-02-20',
#  '2010-02-20',
#  '2010-02-21',
#  '2010-02-25',
#  '2010-02-25',
#  '2010-02-27',
#  '2010-02-28',
#  '2010-02-28',
#  '2010-03-01',
#  '2010-08-01',
#  '2010-02-28',
#  '2010-03-01',
# ...

# %%
len(report)
# Out:
# 2119797

# %%
len(crime)
# Out:
# 2119797

# %%
data.drop("Date Rptd", axis = 1, inplace = True)
data["Date Rptd"] = report
data.drop("DATE OCC", axis = 1, inplace = True)
data["Date Occ"] = crime

# %%
data
# Out:
#              DR_NO  TIME OCC  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0          1307355      1350     13      Newton         1385         2
# 1         11401303        45     14     Pacific         1485         2
# 2         70309629      1515     13      Newton         1324         2
# 3         90631215       150      6   Hollywood          646         2
# 4        100100501      2100      1     Central          176         1
# ...            ...       ...    ...         ...          ...       ...
# 2119792  190506304       840      5      Harbor          569         2
# 2119793  190608903       400      6   Hollywood          644         1
# 2119794  192004409      2100     20     Olympic         2029         2
# 2119795  191716777      1800     17  Devonshire         1795         1
# 2119796  190805435      1615      8     West LA          852         1
#
#          Crm Cd                                        Crm Cd Desc  \
# ...

# %%
data = data.drop(['Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street', 'Weapon Used Cd'], axis=1)

# %%
data['Weapon Desc'] = data['Weapon Desc'].fillna('No Entry')

# %%
data
# Out:
#              DR_NO  TIME OCC  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0          1307355      1350     13      Newton         1385         2
# 1         11401303        45     14     Pacific         1485         2
# 2         70309629      1515     13      Newton         1324         2
# 3         90631215       150      6   Hollywood          646         2
# 4        100100501      2100      1     Central          176         1
# ...            ...       ...    ...         ...          ...       ...
# 2119792  190506304       840      5      Harbor          569         2
# 2119793  190608903       400      6   Hollywood          644         1
# 2119794  192004409      2100     20     Olympic         2029         2
# 2119795  191716777      1800     17  Devonshire         1795         1
# 2119796  190805435      1615      8     West LA          852         1
#
#          Crm Cd                                        Crm Cd Desc  \
# ...

# %%
data['Date Rptd'] = pd.to_datetime(data['Date Rptd'])
# prev_years = data[~(data['Date Rptd'] > '2016-12-31')]
prev_years = data
prev_years
# Out:
#              DR_NO  TIME OCC  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0          1307355      1350     13      Newton         1385         2
# 1         11401303        45     14     Pacific         1485         2
# 2         70309629      1515     13      Newton         1324         2
# 3         90631215       150      6   Hollywood          646         2
# 4        100100501      2100      1     Central          176         1
# ...            ...       ...    ...         ...          ...       ...
# 2119792  190506304       840      5      Harbor          569         2
# 2119793  190608903       400      6   Hollywood          644         1
# 2119794  192004409      2100     20     Olympic         2029         2
# 2119795  191716777      1800     17  Devonshire         1795         1
# 2119796  190805435      1615      8     West LA          852         1
#
#          Crm Cd                                        Crm Cd Desc  \
# ...

# %%
# modf_data = pd.merge(data,prev_years, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)

# %%
# modf_data.to_csv('crimedataset2017to2022.csv')
data.to_csv('crimedata_new_all.csv')
# Out:
# /home/hardik/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
from google.colab import files
files.download('crimedataset2017to2022.csv')

# %%
# modf_data = pd.read_csv("crimedataset2017to2022.csv")
modf_data = pd.read_csv('crimedata_new_all.csv')
modf_data
# Out:
#          Unnamed: 0      DR_NO  TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0                 0    1307355      1350     13      Newton         1385
# 1                 1   11401303        45     14     Pacific         1485
# 2                 2   70309629      1515     13      Newton         1324
# 3                 3   90631215       150      6   Hollywood          646
# 4                 4  100100501      2100      1     Central          176
# ...             ...        ...       ...    ...         ...          ...
# 2119792     2119792  190506304       840      5      Harbor          569
# 2119793     2119793  190608903       400      6   Hollywood          644
# 2119794     2119794  192004409      2100     20     Olympic         2029
# 2119795     2119795  191716777      1800     17  Devonshire         1795
# 2119796     2119796  190805435      1615      8     West LA          852
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# ...

# %%
modf_data.loc[:,"TIME OCC"]
# Out:
# 0          1350
# 1            45
# 2          1515
# 3           150
# 4          2100
#            ...
# 2119792     840
# 2119793     400
# 2119794    2100
# 2119795    1800
# 2119796    1615
# Name: TIME OCC, Length: 2119797, dtype: int64

# %%
time_of_crime = modf_data["TIME OCC"].values.tolist()

# %%
time_of_crime
# Out:
# [1350,
#  45,
#  1515,
#  150,
#  2100,
#  1650,
#  2005,
#  2100,
#  230,
#  2100,
#  1445,
#  2000,
#  245,
#  1745,
#  2030,
#  1735,
#  1225,
#  1100,
#  2000,
#  1820,
#  2345,
#  1630,
#  130,
#  1000,
#  1700,
#  2200,
#  1930,
#  1720,
#  1255,
#  1355,
#  1425,
#  110,
#  2030,
#  1625,
#  1800,
#  1900,
#  1800,
#  1515,
#  55,
#  150,
#  1500,
#  100,
#  1540,
#  1725,
#  2040,
#  2030,
#  100,
#  230,
#  500,
#  30,
#  2330,
#  1955,
#  15,
#  2200,
#  305,
#  250,
#  1825,
#  100,
#  410,
#  420,
#  1930,
#  2300,
#  2110,
#  815,
#  930,
#  1520,
#  1615,
#  800,
#  1700,
#  2000,
#  2050,
#  1,
#  2305,
#  1650,
#  250,
#  15,
#  15,
#  1000,
#  1140,
#  1215,
#  320,
#  1000,
#  1315,
#  1330,
#  1730,
#  1915,
#  2030,
#  125,
#  230,
#  2015,
#  240,
#  530,
#  1140,
#  1500,
#  55,
#  100,
#  2320,
#  1515,
#  1,
#  1940,
#  1900,
#  220,
#  920,
#  1710,
#  200,
#  1700,
#  1730,
#  1515,
#  915,
#  335,
#  1740,
#  2120,
#  510,
#  800,
#  1800,
#  1815,
# ...

# %%
len(time_of_crime)
# Out:
# 2119797

# %%
time_of_crime[0]
# Out:
# 1350

# %%
type(time_of_crime[0])
# Out:
# int

# %%
crimetime = []
for i in range(len(time_of_crime)):
  crimetime.append(str(time_of_crime[i]))
crimetime
# Out:
# ['1350',
#  '45',
#  '1515',
#  '150',
#  '2100',
#  '1650',
#  '2005',
#  '2100',
#  '230',
#  '2100',
#  '1445',
#  '2000',
#  '245',
#  '1745',
#  '2030',
#  '1735',
#  '1225',
#  '1100',
#  '2000',
#  '1820',
#  '2345',
#  '1630',
#  '130',
#  '1000',
#  '1700',
#  '2200',
#  '1930',
#  '1720',
#  '1255',
#  '1355',
#  '1425',
#  '110',
#  '2030',
#  '1625',
#  '1800',
#  '1900',
#  '1800',
#  '1515',
#  '55',
#  '150',
#  '1500',
#  '100',
#  '1540',
#  '1725',
#  '2040',
#  '2030',
#  '100',
#  '230',
#  '500',
#  '30',
#  '2330',
#  '1955',
#  '15',
#  '2200',
#  '305',
#  '250',
#  '1825',
#  '100',
#  '410',
#  '420',
#  '1930',
#  '2300',
#  '2110',
#  '815',
#  '930',
#  '1520',
#  '1615',
#  '800',
#  '1700',
#  '2000',
#  '2050',
#  '1',
#  '2305',
#  '1650',
#  '250',
#  '15',
#  '15',
#  '1000',
#  '1140',
#  '1215',
#  '320',
#  '1000',
#  '1315',
#  '1330',
#  '1730',
#  '1915',
#  '2030',
#  '125',
#  '230',
#  '2015',
#  '240',
#  '530',
#  '1140',
#  '1500',
# ...

# %%
for i in range(len(crimetime)):
  if len(str(crimetime[i])) > 1:
    crimetime[i] = crimetime[i][:-2] + ":" + crimetime[i][-2:] + ":" + "00"
  else:
    crimetime[i] = crimetime[i][:] + ":" + "00" + ":" + "00"
crimetime
# Out:
# ['13:50:00',
#  ':45:00',
#  '15:15:00',
#  '1:50:00',
#  '21:00:00',
#  '16:50:00',
#  '20:05:00',
#  '21:00:00',
#  '2:30:00',
#  '21:00:00',
#  '14:45:00',
#  '20:00:00',
#  '2:45:00',
#  '17:45:00',
#  '20:30:00',
#  '17:35:00',
#  '12:25:00',
#  '11:00:00',
#  '20:00:00',
#  '18:20:00',
#  '23:45:00',
#  '16:30:00',
#  '1:30:00',
#  '10:00:00',
#  '17:00:00',
#  '22:00:00',
#  '19:30:00',
#  '17:20:00',
#  '12:55:00',
#  '13:55:00',
#  '14:25:00',
#  '1:10:00',
#  '20:30:00',
#  '16:25:00',
#  '18:00:00',
#  '19:00:00',
#  '18:00:00',
#  '15:15:00',
#  ':55:00',
#  '1:50:00',
#  '15:00:00',
#  '1:00:00',
#  '15:40:00',
#  '17:25:00',
#  '20:40:00',
#  '20:30:00',
#  '1:00:00',
#  '2:30:00',
#  '5:00:00',
#  ':30:00',
#  '23:30:00',
#  '19:55:00',
#  ':15:00',
#  '22:00:00',
#  '3:05:00',
#  '2:50:00',
#  '18:25:00',
#  '1:00:00',
#  '4:10:00',
#  '4:20:00',
#  '19:30:00',
#  '23:00:00',
#  '21:10:00',
#  '8:15:00',
#  '9:30:00',
#  '15:20:00',
#  '16:15:00',
#  '8:00:00',
# ...

# %%
for i in range(len(crimetime)):
  if len(crimetime[i][:-7]) != 1:
    crimetime[i] = "0" + crimetime[i][:]
crimetime
# Out:
# ['13:50:00',
#  '0:45:00',
#  '15:15:00',
#  '01:50:00',
#  '21:00:00',
#  '16:50:00',
#  '20:05:00',
#  '21:00:00',
#  '02:30:00',
#  '21:00:00',
#  '14:45:00',
#  '20:00:00',
#  '02:45:00',
#  '17:45:00',
#  '20:30:00',
#  '17:35:00',
#  '12:25:00',
#  '11:00:00',
#  '20:00:00',
#  '18:20:00',
#  '23:45:00',
#  '16:30:00',
#  '01:30:00',
#  '10:00:00',
#  '17:00:00',
#  '22:00:00',
#  '19:30:00',
#  '17:20:00',
#  '12:55:00',
#  '13:55:00',
#  '14:25:00',
#  '01:10:00',
#  '20:30:00',
#  '16:25:00',
#  '18:00:00',
#  '19:00:00',
#  '18:00:00',
#  '15:15:00',
#  '0:55:00',
#  '01:50:00',
#  '15:00:00',
#  '01:00:00',
#  '15:40:00',
#  '17:25:00',
#  '20:40:00',
#  '20:30:00',
#  '01:00:00',
#  '02:30:00',
#  '05:00:00',
#  '0:30:00',
#  '23:30:00',
#  '19:55:00',
#  '0:15:00',
#  '22:00:00',
#  '03:05:00',
#  '02:50:00',
#  '18:25:00',
#  '01:00:00',
#  '04:10:00',
#  '04:20:00',
#  '19:30:00',
#  '23:00:00',
#  '21:10:00',
#  '08:15:00',
#  '09:30:00',
#  '15:20:00',
# ...

# %%
modf_data.drop("TIME OCC", axis = 1, inplace = True)
modf_data["Time Occ"] = crimetime

# %%
modf_data
# Out:
#         Unnamed: 0      DR_NO  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0            65782  171917582     19     Mission         1901         2
# 1            65852  220608565      6   Hollywood          645         1
# 2            65853  211914192     19     Mission         1924         2
# 3            66244  221704604     17  Devonshire         1783         1
# 4            66418  172008853     20     Olympic         2026         2
# ...            ...        ...    ...         ...          ...       ...
# 693000     2119792  190506304      5      Harbor          569         2
# 693001     2119793  190608903      6   Hollywood          644         1
# 693002     2119794  192004409     20     Olympic         2029         2
# 693003     2119795  191716777     17  Devonshire         1795         1
# 693004     2119796  190805435      8     West LA          852         1
#
#         Crm Cd                                        Crm Cd Desc  \
# ...

# %%
# modf_data.drop(modf_data.filter(regex="Unnamed"),axis=1, inplace=True)

# %%
del modf_data[modf_data.columns[0]]

# %%
modf_data
# Out:
#              DR_NO  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          1307355     13      Newton         1385         2     900
# 1         11401303     14     Pacific         1485         2     740
# 2         70309629     13      Newton         1324         2     946
# 3         90631215      6   Hollywood          646         2     900
# 4        100100501      1     Central          176         1     122
# ...            ...    ...         ...          ...       ...     ...
# 2119792  190506304      5      Harbor          569         2     627
# 2119793  190608903      6   Hollywood          644         1     648
# 2119794  192004409     20     Olympic         2029         2     930
# 2119795  191716777     17  Devonshire         1795         1     420
# 2119796  190805435      8     West LA          852         1     330
#
#                                                Crm Cd Desc  \
# 0                                 VIOLATION OF COURT ORDER
# ...

# %%
modf_data.to_csv('crime_data_all_new_modified.csv')
# Out:
# /home/hardik/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
files.download('crime_data_all_new_modified.csv')

# %% [markdown]
# EDIT MARCH 15, 16 FOR FORMATTING OF TIME_OCC ATTRIBUTE

# %%
reload_data = pd.read_csv("crime_data_all_new_modified.csv")

# %%
reload_df = pd.DataFrame(reload_data)

# %%
reload_df['Time of Crime'] = reload_df['Date Occ'].map(str) + ':' + reload_df['Time Occ'].map(str)
print(reload_df)
# Out:
#          Unnamed: 0      DR_NO  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0                 0    1307355     13      Newton         1385         2
# 1                 1   11401303     14     Pacific         1485         2
# 2                 2   70309629     13      Newton         1324         2
# 3                 3   90631215      6   Hollywood          646         2
# 4                 4  100100501      1     Central          176         1
# ...             ...        ...    ...         ...          ...       ...
# 2119792     2119792  190506304      5      Harbor          569         2
# 2119793     2119793  190608903      6   Hollywood          644         1
# 2119794     2119794  192004409     20     Olympic         2029         2
# 2119795     2119795  191716777     17  Devonshire         1795         1
# 2119796     2119796  190805435      8     West LA          852         1
#
#          Crm Cd                                        Crm Cd Desc  \
# ...

# %%
reload_df
# Out:
#          Unnamed: 0      DR_NO  AREA    AREA NAME  Rpt Dist No  Part 1-2  \
# 0                 0    1307355     13      Newton         1385         2
# 1                 1   11401303     14     Pacific         1485         2
# 2                 2   70309629     13      Newton         1324         2
# 3                 3   90631215      6   Hollywood          646         2
# 4                 4  100100501      1     Central          176         1
# ...             ...        ...    ...         ...          ...       ...
# 2119792     2119792  190506304      5      Harbor          569         2
# 2119793     2119793  190608903      6   Hollywood          644         1
# 2119794     2119794  192004409     20     Olympic         2029         2
# 2119795     2119795  191716777     17  Devonshire         1795         1
# 2119796     2119796  190805435      8     West LA          852         1
#
#          Crm Cd                                        Crm Cd Desc  \
# ...

# %%
reload_df.to_csv('crime_all_final_copy.csv')

# %%
reload_data.columns
# Out:
# Index(['Unnamed: 0', 'DR_NO', 'AREA ', 'AREA NAME', 'Rpt Dist No', 'Part 1-2',
#        'Crm Cd', 'Crm Cd Desc', 'Mocodes', 'Vict Age', 'Vict Sex',
#        'Vict Descent', 'Premis Cd', 'Premis Desc', 'Weapon Desc', 'Status',
#        'Status Desc', 'Crm Cd 1', 'LOCATION', 'LAT', 'LON', 'Date Rptd',
#        'Date Occ', 'Time Occ', 'Time of Crime'],
#       dtype='object')

# %%
from google.colab import files
files.download('crimedataset17_22.csv')

# %% [markdown]
# EDIT MARCH 26 - RESIZE DATASET FROM 690K TO 2 MILLION TUPLES AS IN ORIGINAL DATASET, TIME_OF_CRIME COLUMN, RENAMED TO TIME_OCC, ORIGINAL TIME_OCC COLUMN REMOVED

# %%
reload_copy = reload_data.copy()

# %%
reload_copy
# Out:
#              DR_NO  AREA   AREA_NAME  RPT_DIST_NO  PART_1_2  CRM_CD  \
# 0          1307355    13      Newton         1385         2     900
# 1         11401303    14     Pacific         1485         2     740
# 2         70309629    13      Newton         1324         2     946
# 3         90631215     6   Hollywood          646         2     900
# 4        100100501     1     Central          176         1     122
# ...            ...   ...         ...          ...       ...     ...
# 2119792  190506304     5      Harbor          569         2     627
# 2119793  190608903     6   Hollywood          644         1     648
# 2119794  192004409    20     Olympic         2029         2     930
# 2119795  191716777    17  Devonshire         1795         1     420
# 2119796  190805435     8     West LA          852         1     330
#
#                                                CRM_CD_DESC  \
# 0                                 VIOLATION OF COURT ORDER
# ...

# %%
reload_copy.columns
# Out:
# Index(['DR_NO', 'AREA', 'AREA_NAME', 'RPT_DIST_NO', 'PART_1_2', 'CRM_CD',
#        'CRM_CD_DESC', 'MOCODES', 'VICT_AGE', 'VICT_SEX', 'VICT_DESCENT',
#        'PREMIS_CD', 'PREMIS_DESC', 'WEAPON_DESC', 'STATUS', 'STATUS_DESC',
#        'CRM_CD_1', 'LOCATION', 'LAT', 'LON', 'DATE_RPTD', 'DATE_OCC',
#        'TIME_OCC'],
#       dtype='object')

# %%
type(reload_copy['Crm Cd 1'][0])
# Out:
# numpy.float64

# %%
reload_copy.drop(reload_copy.filter(regex="Time Occ"),axis=1, inplace=True)

# %%
reload_copy.rename(columns = {'Crm Cd 1':'CRM_CD_1'}, inplace = True)

# %%
reload_copy.to_csv('final.csv', index=False)
